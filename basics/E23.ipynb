# %%
fruit=[
['Apples',12, 'AAA'],['Oranges',1, 'B'],
['Pears',2, 'A'],['Grapes',14, 'UR']]

cars=[
['Cadillac',['Black', 'Big',34500]], # 0 = outer list, 1 = inner list
['Corvette',['Red', 'Little',1000000]],
['Ford',['Blue', 'Medium',1234]],
['BMW',['White', 'Baby',7890]]
]

languages =[
['Python',['Slow',['Terrible', 'Mush']]],
['JavaSCript',['Moderate',['Alright', 'Bizarre']]],
['Perl6',['Moderate',['Fun', 'Weird']]],
['C',['Fast',['Annoying', 'Dangerous']]],
['Forth',['Fast',['Fun', 'Difficult']]],
 ]

# This is a very long methos!!!!! print("\n",fruit[0][1],"\n",fruit[0][2],"\n",fruit[2][1],"\n",fruit[1][0],"\n",fruit[3][0],"\n",fruit[3][1],"\n",fruit[0][0])
# Do this instead!
print(
    fruit[0][1],
    fruit[0][2],
    fruit[2][1],
    fruit[1][0],
    fruit[3][0],
    fruit[3][1],
    fruit[0][0],
    sep="\n"
) # sep tells print what to place between the items you are printing

print(
    cars[0][1][1],
    cars[1][1][0],
    cars[2][1][2],
    cars[3][1][0],
    cars[3][1][2],
    cars[0][1][0],
    cars[0][1][2],
    cars[2][1][0],
    
    sep="\n"
)

print(
    languages[0][1][0],
    languages[1][1][1][0],
    languages[3][1][1][1],
    languages[3][1][0],
    languages[4][1][1][1],
    languages[2][1][1][0],
    languages[3][1][1][0],
    languages[2][1][1][1],
    languages[1][1][0],

    sep="\n"
)
# Out:
# 12
# AAA
# 2
# Oranges
# Grapes
# 14
# Apples
# Big
# Red
# 1234
# White
# 7890
# Black
# 34500
# Blue
# Slow
# Alright
# Dangerous
# Fast
# Difficult
# Fun
# Annoying
# Weird
# Moderate
# Fast
