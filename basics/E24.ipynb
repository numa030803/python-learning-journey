# %%
# Dictionaries
email = {
    "From" : "numadiwale@gmail.com",
    "To" : "num.mad.rt23@dypatil.edu",
    "Subject": "I Love Numa"
}

print(
    email["Subject"],
    email["To"],
    email["From"],
    sep="\n"
)

# To access the values with the help of integers instead of strings
values = list(email.values())
print(values[0])
# Out:
# I Love Numa
# num.mad.rt23@dypatil.edu
# numadiwale@gmail.com
# numadiwale@gmail.com

# %%
fruit = [
    {'kind': 'Apples', 'count':12, 'rating': 'AAA'},
    {'kind': 'Oranges', 'count':1, 'rating': 'B'},
    {'kind': 'Pears', 'count':2, 'rating': 'A'},
    {'kind': 'Grapes', 'count':14, 'rating': 'UR'}
]

print(
    fruit[0]['count'],
    fruit[0]['rating'],
    fruit[2]['count'],
    fruit[1]['kind'],
    fruit[3]['kind'],
    fruit[3]['count'],
    fruit[0]['kind'],

    sep="\n"
    
)

cars = [
    
    {'type': 'Cadillac', 'color': 'Black',
    'size': 'Big', 'miles':34500},
    {'type': 'Corvette', 'color': 'Red',
    'size': 'Little', 'miles':1000000},
    {'type': 'Ford', 'color': 'Blue',
    'size': 'Medium', 'miles':1234},
    {'type': 'BMW', 'color': 'White',
    'size': 'Baby', 'miles':7890}
]

print(
    cars[0]['size'],
    cars[1]['color'],
    cars[2]['miles'],
    cars[3]['color'],
    cars[3]['miles'],
    cars[0]['color'],
    cars[0]['miles'],
    cars[2]['color'],

    sep="\n"
)
    

languages =[
    
    {'name': 'Python', 'speed': 'Slow',
    'opinion':['Terrible', 'Mush']},
    {'name': 'JavaScript', 'speed': 'Moderate',
    'opinion':['Alright', 'Bizarre']},
    {'name': 'Perl6', 'speed': 'Moderate',
    'opinion':['Fun', 'Weird']},
    {'name': 'C','speed': 'Fast',
    'opinion':['Annoying', 'Dangerous']},
    {'name': 'Forth', 'speed': 'Fast',
    'opinion':['Fun', 'Difficult']},
]

print(
    languages[0]['speed'],
    languages[1]['opinion'][0],
    languages[3]['opinion'][1],
    languages[4]['speed'],
    languages[4]['opinion'][1],
    languages[4]['opinion'][0],
    languages[3]['opinion'][0],
    languages[2]['opinion'][1],
    languages[2]['speed'],
    

    sep="\n"
)
# Out:
# 12
# AAA
# 2
# Oranges
# Grapes
# 14
# Apples
# Big
# Red
# 1234
# White
# 7890
# Black
# 34500
# Blue
# Slow
# Alright
# Dangerous
# Fast
# Difficult
# Fun
# Annoying
# Weird
# Moderate

# %%
fruit=[
['Apples',12, 'AAA'],['Oranges',1, 'B'],
['Pears',2, 'A'],['Grapes',14, 'UR']]



cars=[
['Cadillac',['Black', 'Big',34500]], # 0 = outer list, 1 = inner list
['Corvette',['Red', 'Little',1000000]],
['Ford',['Blue', 'Medium',1234]],
['BMW',['White', 'Baby',7890]]
]

languages =[
['Python',['Slow',['Terrible', 'Mush']]],
['JavaSCript',['Moderate',['Alright', 'Bizarre']]],
['Perl6',['Moderate',['Fun', 'Weird']]],
['C',['Fast',['Annoying', 'Dangerous']]],
['Forth',['Fast',['Fun', 'Difficult']]],
 ]
